# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize import TreebankWordTokenizer
from nltk.tag import pos_tag
from nltk import ne_chunk, Tree

# %%
f = open('./path/news.txt','r')
ex = f.readlines()
f.close()
len(ex)
# Out:
# 74

# %%
strEx = " ".join(str(x) for x in ex)

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(strEx)
sent
# Out:
# [('China', 'NNP'),
#  ('sees', 'VBZ'),
#  ('Taiwan', 'NNP'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('breakaway', 'NN'),
#  ('province', 'NN'),
#  ('that', 'WDT'),
#  ('will', 'MD'),
#  ('eventually', 'RB'),
#  ('be', 'VB'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('again', 'RB'),
#  (',', ','),
#  ('but', 'CC'),
#  ('many', 'JJ'),
#  ('Taiwanese', 'NNP'),
#  ('want', 'VBP'),
#  ('a', 'DT'),
#  ('separate', 'JJ'),
#  ('nation', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('dispute', 'NN'),
#  ('with', 'IN'),
#  ('China', 'NNP'),
#  ('has', 'VBZ'),
#  ('left', 'VBN'),
#  ('relations', 'NNS'),
#  ('frayed', 'VBN'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('constant', 'JJ'),
#  ('threat', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('violent', 'NN'),
#  ('flare', 'NN'),
#  ('up', 'IN'),
#  ('that', 'DT'),
#  ('could', 'MD'),
#  ('drag', 'VB'),
#  ('the', 'DT'),
#  ('US', 'NNP'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('fray', 'NN'),
#  ('.', '.'),
#  ('What', 'WP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('history', 'NN'),
#  ('and', 'CC'),
#  ('source', 'NN'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('tension', 'NN'),
#  ('?', '.'),
#  ('The', 'DT'),
#  ('first', 'JJ'),
#  ('known', 'JJ'),
#  ('settlers', 'NNS'),
#  ('in', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('are', 'VBP'),
#  ('Austronesian', 'JJ'),
#  ('tribal', 'JJ'),
#  ('people', 'NNS'),
#  ('thought', 'VBN'),
#  ('to', 'TO'),
#  ('have', 'VB'),
#  ('come', 'VBN'),
#  ('from', 'IN'),
#  ('modern', 'JJ'),
#  ('day', 'NN'),
#  ('southern', 'JJ'),
#  ('China', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('island', 'NN'),
#  ('first', 'RB'),
#  ('appears', 'VBZ'),
#  ('in', 'IN'),
#  ('Chinese', 'JJ'),
#  ('records', 'NNS'),
#  ('in', 'IN'),
#  ('AD239', 'NNP'),
#  (',', ','),
#  ('when', 'WRB'),
#  ('China', 'NNP'),
#  ('sent', 'VBD'),
#  ('an', 'DT'),
#  ('expeditionary', 'JJ'),
#  ('force', 'NN'),
#  ('to', 'TO'),
#  ('explore', 'VB'),
#  ('-', ':'),
#  ('a', 'DT'),
#  ('fact', 'NN'),
#  ('Beijing', 'NNP'),
#  ('uses', 'VBZ'),
#  ('to', 'TO'),
#  ('back', 'VB'),
#  ('its', 'PRP$'),
#  ('territorial', 'JJ'),
#  ('claim', 'NN'),
#  ('.', '.'),
#  ('After', 'IN'),
#  ('a', 'DT'),
#  ('brief', 'JJ'),
#  ('spell', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('Dutch', 'JJ'),
#  ('colony', 'NN'),
#  ('(', '('),
#  ('1624-1661', 'JJ'),
#  (')', ')'),
#  ('Taiwan', 'NNP'),
#  ('was', 'VBD'),
#  ('unquestionably', 'RB'),
#  ('administered', 'VBN'),
#  ('by', 'IN'),
#  ('China', 'NNP'),
#  ("'s", 'POS'),
#  ('Qing', 'VBG'),
#  ('dynasty', 'NN'),
#  ('from', 'IN'),
#  ('1683', 'CD'),
#  ('to', 'TO'),
#  ('1895', 'CD'),
#  ('.', '.'),
#  ('Starting', 'VBG'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('beginning', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('17th', 'JJ'),
#  ('Century', 'NNP'),
#  (',', ','),
#  ('significant', 'JJ'),
#  ('numbers', 'NNS'),
#  ('of', 'IN'),
#  ('migrants', 'NNS'),
#  ('started', 'VBD'),
#  ('arriving', 'VBG'),
#  ('from', 'IN'),
#  ('China', 'NNP'),
#  (',', ','),
#  ('often', 'RB'),
#  ('fleeing', 'VBG'),
#  ('turmoil', 'NN'),
#  ('or', 'CC'),
#  ('hardship', 'NN'),
#  ('.', '.'),
#  ('Most', 'JJS'),
#  ('were', 'VBD'),
#  ('Hoklo', 'NNP'),
#  ('Chinese', 'NNP'),
#  ('from', 'IN'),
#  ('Fujian', 'NNP'),
#  ('(', '('),
#  ('Fukien', 'NNP'),
#  (')', ')'),
#  ('province', 'NN'),
#  ('or', 'CC'),
#  ('were', 'VBD'),
#  ('Hakka', 'NNP'),
#  ('Chinese', 'NNP'),
#  (',', ','),
#  ('largely', 'RB'),
#  ('from', 'IN'),
#  ('Guangdong', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('descendants', 'NNS'),
#  ('of', 'IN'),
#  ('these', 'DT'),
#  ('two', 'CD'),
#  ('migrations', 'NNS'),
#  ('now', 'RB'),
#  ('make', 'VBP'),
#  ('up', 'RP'),
#  ('by', 'IN'),
#  ('far', 'RB'),
#  ('the', 'DT'),
#  ('largest', 'JJS'),
#  ('population', 'NN'),
#  ('group', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('1895', 'CD'),
#  (',', ','),
#  ('following', 'VBG'),
#  ('Japan', 'NNP'),
#  ("'s", 'POS'),
#  ('victory', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('First', 'JJ'),
#  ('Sino-Japanese', 'JJ'),
#  ('War', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Qing', 'JJ'),
#  ('government', 'NN'),
#  ('had', 'VBD'),
#  ('no', 'DT'),
#  ('choice', 'NN'),
#  ('but', 'CC'),
#  ('to', 'TO'),
#  ('cede', 'VB'),
#  ('Taiwan', 'NNP'),
#  ('to', 'TO'),
#  ('Japan', 'NNP'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('after', 'IN'),
#  ('World', 'NNP'),
#  ('War', 'NNP'),
#  ('Two', 'CD'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Republic', 'NNP'),
#  ('of', 'IN'),
#  ('China', 'NNP'),
#  ('-', ':'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('victors', 'NNS'),
#  ('-', ':'),
#  ('began', 'VBD'),
#  ('ruling', 'VBG'),
#  ('Taiwan', 'NNP'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('consent', 'NN'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('allies', 'NNS'),
#  ('the', 'DT'),
#  ('US', 'NNP'),
#  ('and', 'CC'),
#  ('UK', 'NNP'),
#  (',', ','),
#  ('after', 'IN'),
#  ('Japan', 'NNP'),
#  ('surrendered', 'VBD'),
#  ('and', 'CC'),
#  ('relinquished', 'VBD'),
#  ('control', 'NN'),
#  ('of', 'IN'),
#  ('territory', 'NN'),
#  ('it', 'PRP'),
#  ('had', 'VBD'),
#  ('taken', 'VBN'),
#  ('from', 'IN'),
#  ('China', 'NNP'),
#  ('.', '.'),
#  ('However', 'RB'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('next', 'JJ'),
#  ('few', 'JJ'),
#  ('years', 'NNS'),
#  (',', ','),
#  ('Chiang', 'NNP'),
#  ("'s", 'POS'),
#  ('troops', 'NNS'),
#  ('were', 'VBD'),
#  ('beaten', 'VBN'),
#  ('back', 'RB'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('Communist', 'NNP'),
#  ('armies', 'NNS'),
#  ('under', 'IN'),
#  ('Mao', 'NNP'),
#  ('Zedong', 'NNP'),
#  ('.', '.'),
#  ('Chiang', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('remnants', 'NNS'),
#  ('of', 'IN'),
#  ('his', 'PRP$'),
#  ('Kuomintang', 'NNP'),
#  ('(', '('),
#  ('KMT', 'NNP'),
#  (')', ')'),
#  ('government', 'NN'),
#  ('fled', 'VBD'),
#  ('to', 'TO'),
#  ('Taiwan', 'NNP'),
#  ('in', 'IN'),
#  ('1949', 'CD'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('group', 'NN'),
#  (',', ','),
#  ('referred', 'VBD'),
#  ('to', 'TO'),
#  ('as', 'IN'),
#  ('Mainland', 'NNP'),
#  ('Chinese', 'NNP'),
#  ('and', 'CC'),
#  ('then', 'RB'),
#  ('making', 'VBG'),
#  ('up', 'RP'),
#  ('1.5m', 'CD'),
#  ('people', 'NNS'),
#  (',', ','),
#  ('dominated', 'VBD'),
#  ('Taiwan', 'NNP'),
#  ("'s", 'POS'),
#  ('politics', 'NNS'),
#  ('for', 'IN'),
#  ('many', 'JJ'),
#  ('years', 'NNS'),
#  (',', ','),
#  ('even', 'RB'),
#  ('though', 'IN'),
#  ('they', 'PRP'),
#  ('only', 'RB'),
#  ('account', 'VBP'),
#  ('for', 'IN'),
#  ('14', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('population', 'NN'),
#  ('.', '.'),
#  ('Having', 'VBG'),
#  ('inherited', 'VBN'),
#  ('an', 'DT'),
#  ('effective', 'JJ'),
#  ('dictatorship', 'NN'),
#  (',', ','),
#  ('facing', 'VBG'),
#  ('resistance', 'NN'),
#  ('from', 'IN'),
#  ('local', 'JJ'),
#  ('people', 'NNS'),
#  ('resentful', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('228', 'CD'),
#  ('Massacre', 'NNP'),
#  ('and', 'CC'),
#  ('authoritarian', 'JJ'),
#  ('rule', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('under', 'IN'),
#  ('pressure', 'NN'),
#  ('from', 'IN'),
#  ('a', 'DT'),
#  ('growing', 'VBG'),
#  ('democracy', 'NN'),
#  ('movement', 'NN'),
#  (',', ','),
#  ('Chiang', 'NNP'),
#  ("'s", 'POS'),
#  ('son', 'NN'),
#  (',', ','),
#  ('Chiang', 'NNP'),
#  ('Ching-kuo', 'NNP'),
#  (',', ','),
#  ('began', 'VBD'),
#  ('allowing', 'VBG'),
#  ('a', 'DT'),
#  ('process', 'NN'),
#  ('of', 'IN'),
#  ('democratisation', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('eventually', 'RB'),
#  ('led', 'VBD'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('2000', 'CD'),
#  ('election', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('island', 'NN'),
#  ("'s", 'POS'),
#  ('first', 'JJ'),
#  ('non-KMT', 'JJ'),
#  ('president', 'NN'),
#  (',', ','),
#  ('Chen', 'NNP'),
#  ('Shui-bian', 'NNP'),
#  ('.', '.'),
#  ('Where', 'WRB'),
#  ('are', 'VBP'),
#  ('things', 'NNS'),
#  ('at', 'IN'),
#  ('now', 'RB'),
#  ('?', '.'),
#  ('After', 'IN'),
#  ('decades', 'NNS'),
#  ('of', 'IN'),
#  ('hostile', 'JJ'),
#  ('intentions', 'NNS'),
#  ('and', 'CC'),
#  ('angry', 'JJ'),
#  ('rhetoric', 'NN'),
#  (',', ','),
#  ('relations', 'NNS'),
#  ('between', 'IN'),
#  ('China', 'NNP'),
#  ('and', 'CC'),
#  ('Taiwan', 'NNP'),
#  ('started', 'VBD'),
#  ('improving', 'VBG'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('1980s', 'CD'),
#  ('.', '.'),
#  ('China', 'NNP'),
#  ('put', 'VBD'),
#  ('forward', 'RP'),
#  ('a', 'DT'),
#  ('formula', 'NN'),
#  (',', ','),
#  ('known', 'VBN'),
#  ('as', 'IN'),
#  ('``', '``'),
#  ('one', 'CD'),
#  ('country', 'NN'),
#  (',', ','),
#  ('two', 'CD'),
#  ('systems', 'NNS'),
#  ("''", "''"),
#  (',', ','),
#  ('under', 'IN'),
#  ('which', 'WDT'),
#  ('Taiwan', 'NNP'),
#  ('would', 'MD'),
#  ('be', 'VB'),
#  ('given', 'VBN'),
#  ('significant', 'JJ'),
#  ('autonomy', 'NN'),
#  ('if', 'IN'),
#  ('it', 'PRP'),
#  ('accepted', 'VBD'),
#  ('Chinese', 'JJ'),
#  ('reunification', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('offer', 'NN'),
#  ('was', 'VBD'),
#  ('rejected', 'VBN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('Taiwan', 'NNP'),
#  ('did', 'VBD'),
#  ('relax', 'VB'),
#  ('rules', 'NNS'),
#  ('on', 'IN'),
#  ('visits', 'NNS'),
#  ('to', 'TO'),
#  ('and', 'CC'),
#  ('investment', 'NN'),
#  ('in', 'IN'),
#  ('China', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('also', 'RB'),
#  (',', ','),
#  ('in', 'IN'),
#  ('1991', 'CD'),
#  (',', ','),
#  ('proclaimed', 'VBD'),
#  ('the', 'DT'),
#  ('war', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('People', 'NNP'),
#  ("'s", 'POS'),
#  ('Republic', 'NNP'),
#  ('of', 'IN'),
#  ('China', 'NNP'),
#  ('over', 'IN'),
#  ('.', '.'),
#  ('There', 'EX'),
#  ('were', 'VBD'),
#  ('also', 'RB'),
#  ('limited', 'JJ'),
#  ('talks', 'NNS'),
#  ('between', 'IN'),
#  ('the', 'DT'),
#  ('two', 'CD'),
#  ('sides', 'NNS'),
#  ("'", 'POS'),
#  ('unofficial', 'JJ'),
#  ('representatives', 'NNS'),
#  (',', ','),
#  ('though', 'IN'),
#  ('China', 'NNP'),
#  ("'s", 'POS'),
#  ('insistence', 'NN'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('Republic', 'NNP'),
#  ('of', 'IN'),
#  ('China', 'NNP'),
#  ('(', '('),
#  ('ROC', 'NNP'),
#  (')', ')'),
#  ('government', 'NN'),
#  ('is', 'VBZ'),
#  ('illegitimate', 'JJ'),
#  ('prevented', 'JJ'),
#  ('government-to-government', 'JJ'),
#  ('contact', 'NN'),
#  ('.', '.'),
#  ('Beijing', 'NNP'),
#  ('became', 'VBD'),
#  ('alarmed', 'VBN'),
#  ('in', 'IN'),
#  ('2000', 'CD'),
#  (',', ','),
#  ('when', 'WRB'),
#  ('Taiwan', 'NNP'),
#  ('elected', 'VBD'),
#  ('as', 'IN'),
#  ('president', 'NN'),
#  ('Chen', 'NNP'),
#  ('Shui-bian', 'NNP'),
#  (',', ','),
#  ('who', 'WP'),
#  ('had', 'VBD'),
#  ('openly', 'RB'),
#  ('backed', 'VBN'),
#  ('independence', 'NN'),
#  ('.', '.'),
#  ('Mr', 'NNP'),
#  ('Chen', 'NNP'),
#  ('was', 'VBD'),
#  ('re-elected', 'VBN'),
#  ('in', 'IN'),
#  ('2004', 'CD'),
#  (',', ','),
#  ('prompting', 'VBG'),
#  ('China', 'NNP'),
#  ('to', 'TO'),
#  ('pass', 'VB'),
#  ('a', 'DT'),
#  ('so-called', 'JJ'),
#  ('anti-secession', 'NN'),
#  ('law', 'NN'),
#  ('in', 'IN'),
#  ('2005', 'CD'),
#  (',', ','),
#  ('stating', 'VBG'),
#  ('China', 'NNP'),
#  ("'s", 'POS'),
#  ('right', 'NN'),
#  ('to', 'TO'),
#  ('use', 'VB'),
#  ('``', '``'),
#  ('non-peaceful', 'JJ'),
#  ('means', 'NNS'),
#  ("''", "''"),
#  ('against', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('if', 'IN'),
#  ('it', 'PRP'),
#  ('tried', 'VBD'),
#  ('to', 'TO'),
#  ('secede', 'VB'),
#  ('from', 'IN'),
#  ('China', 'NNP'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('2008', 'CD'),
#  (',', ','),
#  ('Ma', 'NNP'),
#  ('Ying-jeou', 'NNP'),
#  ('was', 'VBD'),
#  ('elected', 'VBN'),
#  ('president', 'NN'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('sought', 'VBD'),
#  ('to', 'TO'),
#  ('improve', 'VB'),
#  ('relations', 'NNS'),
#  ('with', 'IN'),
#  ('China', 'NNP'),
#  (',', ','),
#  ('mainly', 'RB'),
#  ('through', 'IN'),
#  ('economic', 'JJ'),
#  ('agreements', 'NNS'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('elections', 'NNS'),
#  ('in', 'IN'),
#  ('January', 'NNP'),
#  ('2016', 'CD'),
#  (',', ','),
#  ('Tsai', 'NNP'),
#  ('Ing-wen', 'NNP'),
#  ('defeated', 'VBD'),
#  ('Kuomintang', 'NNP'),
#  ('party', 'NN'),
#  ('candidate', 'NN'),
#  ('Eric', 'NNP'),
#  ('Chu', 'NNP'),
#  ('.', '.'),
#  ('Mr', 'NNP'),
#  ('Ma', 'NNP'),
#  ('was', 'VBD'),
#  ('barred', 'VBN'),
#  ('by', 'IN'),
#  ('Taiwan', 'NNP'),
#  ("'s", 'POS'),
#  ('constitution', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('seeking', 'VBG'),
#  ('a', 'DT'),
#  ('third', 'JJ'),
#  ('term', 'NN'),
#  ('in', 'IN'),
#  ('office', 'NN'),
#  ('.', '.'),
#  ('Ms', 'NNP'),
#  ('Tsai', 'NNP'),
#  ('leads', 'VBZ'),
#  ('the', 'DT'),
#  ('Democratic', 'JJ'),
#  ('Progressive', 'NNP'),
#  ('Party', 'NNP'),
#  ('(', '('),
#  ('DPP', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('leans', 'VBZ'),
#  ('towards', 'NNS'),
#  ('independence', 'NN'),
#  ('from', 'IN'),
#  ('China', 'NNP'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('December', 'NNP'),
#  ('2016', 'CD'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('spoke', 'VBD'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('then', 'RB'),
#  ('US', 'NNP'),
#  ('President-elect', 'NNP'),
#  ('Donald', 'NNP'),
#  ('Trump', 'NNP'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('phone', 'NN'),
#  ('call', 'NN'),
#  (',', ','),
#  ('in', 'IN'),
#  ('what', 'WP'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('break', 'NN'),
#  ('with', 'IN'),
#  ('US', 'JJ'),
#  ('policy', 'NN'),
#  ('set', 'VBN'),
#  ('in', 'IN'),
#  ('1979', 'CD'),
#  ('when', 'WRB'),
#  ('formal', 'JJ'),
#  ('relations', 'NNS'),
#  ('were', 'VBD'),
#  ('cut', 'VBN'),
#  ('.', '.'),
#  ('So', 'IN'),
#  ('what', 'WP'),
#  ('is', 'VBZ'),
#  ('Taiwan', 'NNP'),
#  ('?', '.'),
#  ('There', 'EX'),
#  ('is', 'VBZ'),
#  ('disagreement', 'JJ'),
#  ('and', 'CC'),
#  ('confusion', 'NN'),
#  ('about', 'IN'),
#  ('what', 'WP'),
#  ('Taiwan', 'NNP'),
#  ('is', 'VBZ'),
#  (',', ','),
#  ('and', 'CC'),
#  ('even', 'RB'),
#  ('what', 'WP'),
#  ('it', 'PRP'),
#  ('should', 'MD'),
#  ('be', 'VB'),
#  ('called', 'VBN'),
#  ('.', '.'),
#  ('Chiang', 'NNP'),
#  ('Kai-shek', 'NNP'),
#  ("'s", 'POS'),
#  ('Republic', 'NNP'),
#  ('of', 'IN'),
#  ('China', 'NNP'),
#  ('(', '('),
#  ('ROC', 'NNP'),
#  (')', ')'),
#  ('government', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('fled', 'VBD'),
#  ('the', 'DT'),
#  ('mainland', 'NN'),
#  ('to', 'TO'),
#  ('Taiwan', 'NNP'),
#  ('in', 'IN'),
#  ('1949', 'CD'),
#  (',', ','),
#  ('at', 'IN'),
#  ('first', 'RB'),
#  ('claimed', 'VBN'),
#  ('to', 'TO'),
#  ('represent', 'VB'),
#  ('the', 'DT'),
#  ('whole', 'NN'),
#  ('of', 'IN'),
#  ('China', 'NNP'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('it', 'PRP'),
#  ('intended', 'VBD'),
#  ('to', 'TO'),
#  ('re-occupy', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('held', 'VBD'),
#  ('China', 'NNP'),
#  ("'s", 'POS'),
#  ('seat', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('United', 'NNP'),
#  ('Nations', 'NNP'),
#  ('Security', 'NNP'),
#  ('Council', 'NNP'),
#  ('and', 'CC'),
#  ('was', 'VBD'),
#  ('recognised', 'VBN'),
#  ('by', 'IN'),
#  ('many', 'JJ'),
#  ('Western', 'JJ'),
#  ('nations', 'NNS'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('only', 'JJ'),
#  ('Chinese', 'JJ'),
#  ('government', 'NN'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('in', 'IN'),
#  ('1971', 'CD'),
#  (',', ','),
#  ('the', 'DT'),
#  ('UN', 'NNP'),
#  ('switched', 'VBD'),
#  ('diplomatic', 'JJ'),
#  ('recognition', 'NN'),
#  ('to', 'TO'),
#  ('Beijing', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('ROC', 'NNP'),
#  ('government', 'NN'),
#  ('was', 'VBD'),
#  ('forced', 'VBN'),
#  ('out', 'RP'),
#  ('.', '.'),
#  ('Since', 'IN'),
#  ('then', 'RB'),
#  ('the', 'DT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('countries', 'NNS'),
#  ('that', 'WDT'),
#  ('recognise', 'VBP'),
#  ('the', 'DT'),
#  ('ROC', 'NNP'),
#  ('government', 'NN'),
#  ('diplomatically', 'RB'),
#  ('has', 'VBZ'),
#  ('fallen', 'VBN'),
#  ('to', 'TO'),
#  ('about', 'IN'),
#  ('20', 'CD'),
#  ('.', '.'),
#  ('China', 'NNP'),
#  ('regards', 'NNS'),
#  ('Taiwan', 'NNP'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('breakaway', 'NN'),
#  ('province', 'NN'),
#  ('which', 'WDT'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('vowed', 'VBN'),
#  ('to', 'TO'),
#  ('retake', 'VB'),
#  (',', ','),
#  ('by', 'IN'),
#  ('force', 'NN'),
#  ('if', 'IN'),
#  ('necessary', 'JJ'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('Taiwan', 'NNP'),
#  ("'s", 'POS'),
#  ('leaders', 'NNS'),
#  ('say', 'VBP'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('clearly', 'RB'),
#  ('much', 'RB'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('a', 'DT'),
#  ('province', 'NN'),
#  (',', ','),
#  ('arguing', 'VBG'),
#  ('that', 'IN'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('sovereign', 'JJ'),
#  ('state', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('has', 'VBZ'),
#  ('its', 'PRP$'),
#  ('own', 'JJ'),
#  ('constitution', 'NN'),
#  (',', ','),
#  ('democratically-elected', 'JJ'),
#  ('leaders', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('about', 'IN'),
#  ('300,000', 'CD'),
#  ('active', 'JJ'),
#  ('troops', 'NNS'),
#  ('in', 'IN'),
#  ('its', 'PRP$'),
#  ('armed', 'JJ'),
#  ('forces', 'NNS'),
#  ('.', '.'),
#  ('Given', 'VBN'),
#  ('the', 'DT'),
#  ('huge', 'JJ'),
#  ('divide', 'NN'),
#  ('between', 'IN'),
#  ('these', 'DT'),
#  ('two', 'CD'),
#  ('positions', 'NNS'),
#  (',', ','),
#  ('most', 'JJS'),
#  ('other', 'JJ'),
#  ('countries', 'NNS'),
#  ('seem', 'VBP'),
#  ('happy', 'JJ'),
#  ('to', 'TO'),
#  ('accept', 'VB'),
#  ('the', 'DT'),
#  ('current', 'JJ'),
#  ('ambiguity', 'NN'),
#  (',', ','),
#  ('whereby', 'WRB'),
#  ('Taiwan', 'NNP'),
#  ('has', 'VBZ'),
#  ('most', 'JJS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('characteristics', 'NNS'),
#  ('of', 'IN'),
#  ('an', 'DT'),
#  ('independent', 'JJ'),
#  ('state', 'NN'),
#  (',', ','),
#  ('even', 'RB'),
#  ('if', 'IN'),
#  ('its', 'PRP$'),
#  ('legal', 'JJ'),
#  ('status', 'NN'),
#  ('remains', 'VBZ'),
#  ('unclear', 'JJ'),
#  ('.', '.'),
#  ('How', 'WRB'),
#  ('much', 'JJ'),
#  ('of', 'IN'),
#  ('an', 'DT'),
#  ('issue', 'NN'),
#  ('is', 'VBZ'),
#  ('independence', 'VBN'),
#  ('in', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('?', '.'),
#  ('While', 'IN'),
#  ('political', 'JJ'),
#  ('progress', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('slow', 'JJ'),
#  (',', ','),
#  ('links', 'NNS'),
#  ('between', 'IN'),
#  ('the', 'DT'),
#  ('two', 'CD'),
#  ('peoples', 'NNS'),
#  ('and', 'CC'),
#  ('economies', 'NNS'),
#  ('have', 'VBP'),
#  ('grown', 'VBN'),
#  ('sharply', 'RB'),
#  ('.', '.'),
#  ('Taiwanese', 'JJ'),
#  ('companies', 'NNS'),
#  ('have', 'VBP'),
#  ('invested', 'VBN'),
#  ('about', 'IN'),
#  ('$', '$'),
#  ('60bn', 'CD'),
#  ('(', '('),
#  ('£40bn', 'NN'),
#  (')', ')'),
#  ('in', 'IN'),
#  ('China', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('up', 'RB'),
#  ('to', 'TO'),
#  ('one', 'CD'),
#  ('million', 'CD'),
#  ('Taiwanese', 'NNPS'),
#  ('now', 'RB'),
#  ('live', 'VBP'),
#  ('there', 'RB'),
#  (',', ','),
#  ('many', 'JJ'),
#  ('running', 'VBG'),
#  ('Taiwanese', 'JJ'),
#  ('factories', 'NNS'),
#  ('.', '.'),
#  ('Some', 'DT'),
#  ('Taiwanese', 'JJ'),
#  ('worry', 'VBP'),
#  ('their', 'PRP$'),
#  ('economy', 'NN'),
#  ('is', 'VBZ'),
#  ('now', 'RB'),
#  ('dependent', 'JJ'),
#  ('on', 'IN'),
#  ('China', 'NNP'),
#  ('.', '.'),
#  ('Others', 'NNS'),
#  ('point', 'VBP'),
#  ('out', 'RP'),
#  ('that', 'IN'),
#  ('closer', 'JJR'),
#  ('business', 'NN'),
#  ('ties', 'NNS'),
#  ('makes', 'VBZ'),
#  ('Chinese', 'JJ'),
#  ('military', 'JJ'),
#  ('action', 'NN'),
#  ('less', 'RBR'),
#  ('likely', 'RB'),
#  (',', ','),
#  ('because', 'IN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('cost', 'NN'),
#  ('to', 'TO'),
#  ('China', 'NNP'),
#  ("'s", 'POS'),
#  ('own', 'JJ'),
#  ('economy', 'NN'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('controversial', 'JJ'),
#  ...]

# %% [markdown]
# 自訂名詞片語 NP = 冠詞 DT + 任意數量的形容詞 JJ + 名詞 NN

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   China/NNP
#   sees/VBZ
#   Taiwan/NNP
#   as/IN
#   (NP a/DT breakaway/NN)
#   (NP province/NN)
#   that/WDT
#   will/MD
#   eventually/RB
#   be/VB
#   (NP part/NN)
#   of/IN
#   (NP the/DT country/NN)
#   again/RB
#   ,/,
#   but/CC
#   many/JJ
#   Taiwanese/NNP
#   want/VBP
#   (NP a/DT separate/JJ nation/NN)
#   ./.
#   (NP The/DT dispute/NN)
#   with/IN
#   China/NNP
#   has/VBZ
#   left/VBN
#   relations/NNS
#   frayed/VBN
#   and/CC
#   (NP a/DT constant/JJ threat/NN)
#   of/IN
#   (NP a/DT violent/NN)
#   (NP flare/NN)
#   up/IN
#   that/DT
#   could/MD
#   drag/VB
#   the/DT
#   US/NNP
#   into/IN
#   (NP the/DT fray/NN)
#   ./.
#   What/WP
#   is/VBZ
#   (NP the/DT history/NN)
#   and/CC
#   (NP source/NN)
#   of/IN
#   (NP this/DT tension/NN)
#   ?/.
#   The/DT
#   first/JJ
#   known/JJ
#   settlers/NNS
#   in/IN
#   Taiwan/NNP
#   are/VBP
#   Austronesian/JJ
#   tribal/JJ
#   people/NNS
#   thought/VBN
#   to/TO
#   have/VB
#   come/VBN
#   from/IN
#   (NP modern/JJ day/NN)
#   southern/JJ
#   China/NNP
#   ./.
#   (NP The/DT island/NN)
#   first/RB
#   appears/VBZ
#   in/IN
#   Chinese/JJ
#   records/NNS
#   in/IN
#   AD239/NNP
#   ,/,
#   when/WRB
#   China/NNP
#   sent/VBD
#   (NP an/DT expeditionary/JJ force/NN)
#   to/TO
#   explore/VB
#   -/:
#   (NP a/DT fact/NN)
#   Beijing/NNP
#   uses/VBZ
#   to/TO
#   back/VB
#   its/PRP$
#   (NP territorial/JJ claim/NN)
#   ./.
#   After/IN
#   (NP a/DT brief/JJ spell/NN)
#   as/IN
#   (NP a/DT Dutch/JJ colony/NN)
#   (/(
#   1624-1661/JJ
#   )/)
#   Taiwan/NNP
#   was/VBD
#   unquestionably/RB
#   administered/VBN
#   by/IN
#   China/NNP
#   's/POS
#   Qing/VBG
#   (NP dynasty/NN)
#   from/IN
#   1683/CD
#   to/TO
#   1895/CD
#   ./.
#   Starting/VBG
#   at/IN
#   (NP the/DT beginning/NN)
#   of/IN
#   the/DT
#   17th/JJ
#   Century/NNP
#   ,/,
#   significant/JJ
#   numbers/NNS
#   of/IN
#   migrants/NNS
#   started/VBD
#   arriving/VBG
#   from/IN
#   China/NNP
#   ,/,
#   often/RB
#   fleeing/VBG
#   (NP turmoil/NN)
#   or/CC
#   (NP hardship/NN)
#   ./.
#   Most/JJS
#   were/VBD
#   Hoklo/NNP
#   Chinese/NNP
#   from/IN
#   Fujian/NNP
#   (/(
#   Fukien/NNP
#   )/)
#   (NP province/NN)
#   or/CC
#   were/VBD
#   Hakka/NNP
#   Chinese/NNP
#   ,/,
#   largely/RB
#   from/IN
#   Guangdong/NNP
#   ./.
#   The/DT
#   descendants/NNS
#   of/IN
#   these/DT
#   two/CD
#   migrations/NNS
#   now/RB
#   make/VBP
#   up/RP
#   by/IN
#   far/RB
#   the/DT
#   largest/JJS
#   (NP population/NN)
#   (NP group/NN)
#   ./.
#   In/IN
#   1895/CD
#   ,/,
#   following/VBG
#   Japan/NNP
#   's/POS
#   (NP victory/NN)
#   in/IN
#   the/DT
#   First/JJ
#   Sino-Japanese/JJ
#   War/NNP
#   ,/,
#   (NP the/DT Qing/JJ government/NN)
#   had/VBD
#   (NP no/DT choice/NN)
#   but/CC
#   to/TO
#   cede/VB
#   Taiwan/NNP
#   to/TO
#   Japan/NNP
#   ./.
#   But/CC
#   after/IN
#   World/NNP
#   War/NNP
#   Two/CD
#   ,/,
#   the/DT
#   Republic/NNP
#   of/IN
#   China/NNP
#   -/:
#   one/CD
#   of/IN
#   the/DT
#   victors/NNS
#   -/:
#   began/VBD
#   ruling/VBG
#   Taiwan/NNP
#   with/IN
#   (NP the/DT consent/NN)
#   of/IN
#   its/PRP$
#   allies/NNS
#   the/DT
#   US/NNP
#   and/CC
#   UK/NNP
#   ,/,
#   after/IN
#   Japan/NNP
#   surrendered/VBD
#   and/CC
#   relinquished/VBD
#   (NP control/NN)
#   of/IN
#   (NP territory/NN)
#   it/PRP
#   had/VBD
#   taken/VBN
#   from/IN
#   China/NNP
#   ./.
#   However/RB
#   in/IN
#   the/DT
#   next/JJ
#   few/JJ
#   years/NNS
#   ,/,
#   Chiang/NNP
#   's/POS
#   troops/NNS
#   were/VBD
#   beaten/VBN
#   back/RB
#   by/IN
#   the/DT
#   Communist/NNP
#   armies/NNS
#   under/IN
#   Mao/NNP
#   Zedong/NNP
#   ./.
#   Chiang/NNP
#   and/CC
#   the/DT
#   remnants/NNS
#   of/IN
#   his/PRP$
#   Kuomintang/NNP
#   (/(
#   KMT/NNP
#   )/)
#   (NP government/NN)
#   fled/VBD
#   to/TO
#   Taiwan/NNP
#   in/IN
#   1949/CD
#   ./.
#   (NP This/DT group/NN)
#   ,/,
#   referred/VBD
#   to/TO
#   as/IN
#   Mainland/NNP
#   Chinese/NNP
#   and/CC
#   then/RB
#   making/VBG
#   up/RP
#   1.5m/CD
#   people/NNS
#   ,/,
#   dominated/VBD
#   Taiwan/NNP
#   's/POS
#   politics/NNS
#   for/IN
#   many/JJ
#   years/NNS
#   ,/,
#   even/RB
#   though/IN
#   they/PRP
#   only/RB
#   account/VBP
#   for/IN
#   14/CD
#   (NP %/NN)
#   of/IN
#   (NP the/DT population/NN)
#   ./.
#   Having/VBG
#   inherited/VBN
#   (NP an/DT effective/JJ dictatorship/NN)
#   ,/,
#   facing/VBG
#   (NP resistance/NN)
#   from/IN
#   local/JJ
#   people/NNS
#   (NP resentful/NN)
#   of/IN
#   the/DT
#   228/CD
#   Massacre/NNP
#   and/CC
#   (NP authoritarian/JJ rule/NN)
#   ,/,
#   and/CC
#   under/IN
#   (NP pressure/NN)
#   from/IN
#   a/DT
#   growing/VBG
#   (NP democracy/NN)
#   (NP movement/NN)
#   ,/,
#   Chiang/NNP
#   's/POS
#   (NP son/NN)
#   ,/,
#   Chiang/NNP
#   Ching-kuo/NNP
#   ,/,
#   began/VBD
#   allowing/VBG
#   (NP a/DT process/NN)
#   of/IN
#   (NP democratisation/NN)
#   ,/,
#   which/WDT
#   eventually/RB
#   led/VBD
#   to/TO
#   the/DT
#   2000/CD
#   (NP election/NN)
#   of/IN
#   (NP the/DT island/NN)
#   's/POS
#   (NP first/JJ non-KMT/JJ president/NN)
#   ,/,
#   Chen/NNP
#   Shui-bian/NNP
#   ./.
#   Where/WRB
#   are/VBP
#   things/NNS
#   at/IN
#   now/RB
#   ?/.
#   After/IN
#   decades/NNS
#   of/IN
#   hostile/JJ
#   intentions/NNS
#   and/CC
#   (NP angry/JJ rhetoric/NN)
#   ,/,
#   relations/NNS
#   between/IN
#   China/NNP
#   and/CC
#   Taiwan/NNP
#   started/VBD
#   improving/VBG
#   in/IN
#   the/DT
#   1980s/CD
#   ./.
#   China/NNP
#   put/VBD
#   forward/RP
#   (NP a/DT formula/NN)
#   ,/,
#   known/VBN
#   as/IN
#   ``/``
#   one/CD
#   (NP country/NN)
#   ,/,
#   two/CD
#   systems/NNS
#   ''/''
#   ,/,
#   under/IN
#   which/WDT
#   Taiwan/NNP
#   would/MD
#   be/VB
#   given/VBN
#   (NP significant/JJ autonomy/NN)
#   if/IN
#   it/PRP
#   accepted/VBD
#   (NP Chinese/JJ reunification/NN)
#   ./.
#   (NP The/DT offer/NN)
#   was/VBD
#   rejected/VBN
#   ,/,
#   but/CC
#   Taiwan/NNP
#   did/VBD
#   relax/VB
#   rules/NNS
#   on/IN
#   visits/NNS
#   to/TO
#   and/CC
#   (NP investment/NN)
#   in/IN
#   China/NNP
#   ./.
#   It/PRP
#   also/RB
#   ,/,
#   in/IN
#   1991/CD
#   ,/,
#   proclaimed/VBD
#   (NP the/DT war/NN)
#   with/IN
#   the/DT
#   People/NNP
#   's/POS
#   Republic/NNP
#   of/IN
#   China/NNP
#   over/IN
#   ./.
#   There/EX
#   were/VBD
#   also/RB
#   limited/JJ
#   talks/NNS
#   between/IN
#   the/DT
#   two/CD
#   sides/NNS
#   '/POS
#   unofficial/JJ
#   representatives/NNS
#   ,/,
#   though/IN
#   China/NNP
#   's/POS
#   (NP insistence/NN)
#   that/IN
#   the/DT
#   Republic/NNP
#   of/IN
#   China/NNP
#   (/(
#   ROC/NNP
#   )/)
#   (NP government/NN)
#   is/VBZ
#   (NP
#     illegitimate/JJ
#     prevented/JJ
#     government-to-government/JJ
#     contact/NN)
#   ./.
#   Beijing/NNP
#   became/VBD
#   alarmed/VBN
#   in/IN
#   2000/CD
#   ,/,
#   when/WRB
#   Taiwan/NNP
#   elected/VBD
#   as/IN
#   (NP president/NN)
#   Chen/NNP
#   Shui-bian/NNP
#   ,/,
#   who/WP
#   had/VBD
#   openly/RB
#   backed/VBN
#   (NP independence/NN)
#   ./.
#   Mr/NNP
#   Chen/NNP
#   was/VBD
#   re-elected/VBN
#   in/IN
#   2004/CD
#   ,/,
#   prompting/VBG
#   China/NNP
#   to/TO
#   pass/VB
#   (NP a/DT so-called/JJ anti-secession/NN)
#   (NP law/NN)
#   in/IN
#   2005/CD
#   ,/,
#   stating/VBG
#   China/NNP
#   's/POS
#   (NP right/NN)
#   to/TO
#   use/VB
#   ``/``
#   non-peaceful/JJ
#   means/NNS
#   ''/''
#   against/IN
#   Taiwan/NNP
#   if/IN
#   it/PRP
#   tried/VBD
#   to/TO
#   secede/VB
#   from/IN
#   China/NNP
#   ./.
#   In/IN
#   2008/CD
#   ,/,
#   Ma/NNP
#   Ying-jeou/NNP
#   was/VBD
#   elected/VBN
#   (NP president/NN)
#   ./.
#   He/PRP
#   sought/VBD
#   to/TO
#   improve/VB
#   relations/NNS
#   with/IN
#   China/NNP
#   ,/,
#   mainly/RB
#   through/IN
#   economic/JJ
#   agreements/NNS
#   ./.
#   In/IN
#   elections/NNS
#   in/IN
#   January/NNP
#   2016/CD
#   ,/,
#   Tsai/NNP
#   Ing-wen/NNP
#   defeated/VBD
#   Kuomintang/NNP
#   (NP party/NN)
#   (NP candidate/NN)
#   Eric/NNP
#   Chu/NNP
#   ./.
#   Mr/NNP
#   Ma/NNP
#   was/VBD
#   barred/VBN
#   by/IN
#   Taiwan/NNP
#   's/POS
#   (NP constitution/NN)
#   from/IN
#   the/DT
#   seeking/VBG
#   (NP a/DT third/JJ term/NN)
#   in/IN
#   (NP office/NN)
#   ./.
#   Ms/NNP
#   Tsai/NNP
#   leads/VBZ
#   the/DT
#   Democratic/JJ
#   Progressive/NNP
#   Party/NNP
#   (/(
#   DPP/NNP
#   )/)
#   ,/,
#   which/WDT
#   leans/VBZ
#   towards/NNS
#   (NP independence/NN)
#   from/IN
#   China/NNP
#   ./.
#   In/IN
#   December/NNP
#   2016/CD
#   ,/,
#   she/PRP
#   spoke/VBD
#   to/TO
#   the/DT
#   then/RB
#   US/NNP
#   President-elect/NNP
#   Donald/NNP
#   Trump/NNP
#   in/IN
#   (NP a/DT phone/NN)
#   (NP call/NN)
#   ,/,
#   in/IN
#   what/WP
#   was/VBD
#   (NP a/DT break/NN)
#   with/IN
#   (NP US/JJ policy/NN)
#   set/VBN
#   in/IN
#   1979/CD
#   when/WRB
#   formal/JJ
#   relations/NNS
#   were/VBD
#   cut/VBN
#   ./.
#   So/IN
#   what/WP
#   is/VBZ
#   Taiwan/NNP
#   ?/.
#   There/EX
#   is/VBZ
#   disagreement/JJ
#   and/CC
#   (NP confusion/NN)
#   about/IN
#   what/WP
#   Taiwan/NNP
#   is/VBZ
#   ,/,
#   and/CC
#   even/RB
#   what/WP
#   it/PRP
#   should/MD
#   be/VB
#   called/VBN
#   ./.
#   Chiang/NNP
#   Kai-shek/NNP
#   's/POS
#   Republic/NNP
#   of/IN
#   China/NNP
#   (/(
#   ROC/NNP
#   )/)
#   (NP government/NN)
#   ,/,
#   which/WDT
#   fled/VBD
#   (NP the/DT mainland/NN)
#   to/TO
#   Taiwan/NNP
#   in/IN
#   1949/CD
#   ,/,
#   at/IN
#   first/RB
#   claimed/VBN
#   to/TO
#   represent/VB
#   (NP the/DT whole/NN)
#   of/IN
#   China/NNP
#   ,/,
#   which/WDT
#   it/PRP
#   intended/VBD
#   to/TO
#   (NP re-occupy/NN)
#   ./.
#   It/PRP
#   held/VBD
#   China/NNP
#   's/POS
#   (NP seat/NN)
#   on/IN
#   the/DT
#   United/NNP
#   Nations/NNP
#   Security/NNP
#   Council/NNP
#   and/CC
#   was/VBD
#   recognised/VBN
#   by/IN
#   many/JJ
#   Western/JJ
#   nations/NNS
#   as/IN
#   (NP the/DT only/JJ Chinese/JJ government/NN)
#   ./.
#   But/CC
#   in/IN
#   1971/CD
#   ,/,
#   the/DT
#   UN/NNP
#   switched/VBD
#   (NP diplomatic/JJ recognition/NN)
#   to/TO
#   Beijing/NNP
#   and/CC
#   the/DT
#   ROC/NNP
#   (NP government/NN)
#   was/VBD
#   forced/VBN
#   out/RP
#   ./.
#   Since/IN
#   then/RB
#   (NP the/DT number/NN)
#   of/IN
#   countries/NNS
#   that/WDT
#   recognise/VBP
#   the/DT
#   ROC/NNP
#   (NP government/NN)
#   diplomatically/RB
#   has/VBZ
#   fallen/VBN
#   to/TO
#   about/IN
#   20/CD
#   ./.
#   China/NNP
#   regards/NNS
#   Taiwan/NNP
#   as/IN
#   (NP a/DT breakaway/NN)
#   (NP province/NN)
#   which/WDT
#   it/PRP
#   has/VBZ
#   vowed/VBN
#   to/TO
#   retake/VB
#   ,/,
#   by/IN
#   (NP force/NN)
#   if/IN
#   necessary/JJ
#   ./.
#   But/CC
#   Taiwan/NNP
#   's/POS
#   leaders/NNS
#   say/VBP
#   it/PRP
#   is/VBZ
#   clearly/RB
#   much/RB
#   more/JJR
#   than/IN
#   (NP a/DT province/NN)
#   ,/,
#   arguing/VBG
#   that/IN
#   it/PRP
#   is/VBZ
#   (NP a/DT sovereign/JJ state/NN)
#   ./.
#   It/PRP
#   has/VBZ
#   its/PRP$
#   (NP own/JJ constitution/NN)
#   ,/,
#   democratically-elected/JJ
#   leaders/NNS
#   ,/,
#   and/CC
#   about/IN
#   300,000/CD
#   active/JJ
#   troops/NNS
#   in/IN
#   its/PRP$
#   armed/JJ
#   forces/NNS
#   ./.
#   Given/VBN
#   (NP the/DT huge/JJ divide/NN)
#   between/IN
#   these/DT
#   two/CD
#   positions/NNS
#   ,/,
#   most/JJS
#   other/JJ
#   countries/NNS
#   seem/VBP
#   happy/JJ
#   to/TO
#   accept/VB
#   (NP the/DT current/JJ ambiguity/NN)
#   ,/,
#   whereby/WRB
#   Taiwan/NNP
#   has/VBZ
#   most/JJS
#   of/IN
#   the/DT
#   characteristics/NNS
#   of/IN
#   (NP an/DT independent/JJ state/NN)
#   ,/,
#   even/RB
#   if/IN
#   its/PRP$
#   (NP legal/JJ status/NN)
#   remains/VBZ
#   unclear/JJ
#   ./.
#   How/WRB
#   much/JJ
#   of/IN
#   (NP an/DT issue/NN)
#   is/VBZ
#   independence/VBN
#   in/IN
#   Taiwan/NNP
#   ?/.
#   While/IN
#   (NP political/JJ progress/NN)
#   has/VBZ
#   been/VBN
#   slow/JJ
#   ,/,
#   links/NNS
#   between/IN
#   the/DT
#   two/CD
#   peoples/NNS
#   and/CC
#   economies/NNS
#   have/VBP
#   grown/VBN
#   sharply/RB
#   ./.
#   Taiwanese/JJ
#   companies/NNS
#   have/VBP
#   invested/VBN
#   about/IN
#   $/$
#   60bn/CD
#   (/(
#   (NP £40bn/NN)
#   )/)
#   in/IN
#   China/NNP
#   ,/,
#   and/CC
#   up/RB
#   to/TO
#   one/CD
#   million/CD
#   Taiwanese/NNPS
#   now/RB
#   live/VBP
#   there/RB
#   ,/,
#   many/JJ
#   running/VBG
#   Taiwanese/JJ
#   factories/NNS
#   ./.
#   Some/DT
#   Taiwanese/JJ
#   worry/VBP
#   their/PRP$
#   (NP economy/NN)
#   is/VBZ
#   now/RB
#   dependent/JJ
#   on/IN
#   China/NNP
#   ./.
#   Others/NNS
#   point/VBP
#   out/RP
#   that/IN
#   closer/JJR
#   (NP business/NN)
#   ties/NNS
#   makes/VBZ
#   (NP Chinese/JJ military/JJ action/NN)
#   less/RBR
#   likely/RB
#   ,/,
#   because/IN
#   of/IN
#   (NP the/DT cost/NN)
#   to/TO
#   China/NNP
#   's/POS
#   (NP own/JJ economy/NN)
#   ./.
#   (NP A/DT controversial/JJ trade/NN)
#   (NP agreement/NN)
#   sparked/VBD
#   the/DT
#   ``/``
#   Sunflower/NNP
#   Movement/NNP
#   ''/''
#   in/IN
#   2014/CD
#   where/WRB
#   students/NNS
#   and/CC
#   activists/NNS
#   occupied/VBD
#   Taiwan/NNP
#   's/POS
#   (NP parliament/NN)
#   (NP protesting/NN)
#   against/IN
#   what/WP
#   they/PRP
#   call/VBP
#   China/NNP
#   's/POS
#   growing/VBG
#   (NP influence/NN)
#   over/IN
#   Taiwan/NNP
#   ./.
#   Officially/RB
#   ,/,
#   the/DT
#   Democratic/JJ
#   Progressive/NNP
#   Party/NNP
#   (/(
#   DPP/NNP
#   )/)
#   still/RB
#   favours/VBZ
#   (NP eventual/JJ independence/NN)
#   for/IN
#   Taiwan/NNP
#   ,/,
#   while/IN
#   the/DT
#   KMT/NNP
#   favours/VBZ
#   (NP eventual/JJ re-unification/NN)
#   ./.
#   Opinion/NNP
#   polls/VBZ
#   show/VBP
#   only/RB
#   (NP a/DT small/JJ minority/NN)
#   of/IN
#   (NP Taiwanese/JJ support/NN)
#   pursuing/VBG
#   one/CD
#   or/CC
#   the/DT
#   other/JJ
#   at/IN
#   (NP the/DT moment/NN)
#   ,/,
#   with/IN
#   most/RBS
#   preferring/VBG
#   to/TO
#   stick/VB
#   with/IN
#   (NP the/DT current/JJ middle/NN)
#   (NP ground/NN)
#   ./.
#   Yet/CC
#   more/JJR
#   and/CC
#   more/JJR
#   people/NNS
#   say/VBP
#   they/PRP
#   feel/VBP
#   Taiwanese/JJ
#   rather/RB
#   than/IN
#   Chinese/NNPS
#   ./.
#   Support/NNP
#   for/IN
#   the/DT
#   DPP/NNP
#   increased/VBD
#   at/IN
#   the/DT
#   January/NNP
#   2016/CD
#   (NP election/NN)
#   ./.
#   This/DT
#   was/VBD
#   partly/RB
#   because/IN
#   of/IN
#   (NP dissatisfaction/NN)
#   with/IN
#   the/DT
#   KMT/NNP
#   's/POS
#   (NP handling/NN)
#   of/IN
#   economic/JJ
#   matters/NNS
#   ,/,
#   from/IN
#   (NP the/DT wealth/NN)
#   (NP gap/NN)
#   to/TO
#   (NP high/JJ housing/NN)
#   prices/NNS
#   ,/,
#   and/CC
#   partly/RB
#   because/IN
#   of/IN
#   worries/NNS
#   that/WDT
#   Mr/NNP
#   Ma/NNP
#   's/POS
#   (NP administration/NN)
#   was/VBD
#   making/VBG
#   Taiwan/NNP
#   too/RB
#   dependent/JJ
#   on/IN
#   Beijing/NNP
#   ./.
#   What/WP
#   (NP role/NN)
#   does/VBZ
#   the/DT
#   US/NNP
#   (NP play/NN)
#   ?/.
#   The/DT
#   US/NNP
#   is/VBZ
#   by/IN
#   far/RB
#   Taiwan/NNP
#   's/POS
#   most/RBS
#   (NP important/JJ friend/NN)
#   ,/,
#   and/CC
#   its/PRP$
#   (NP only/JJ ally/NN)
#   ./.
#   (NP The/DT relationship/NN)
#   ,/,
#   forged/VBN
#   during/IN
#   World/NNP
#   War/NNP
#   Two/CD
#   and/CC
#   the/DT
#   Cold/NNP
#   War/NNP
#   ,/,
#   underwent/VBD
#   its/PRP$
#   sternest/JJS
#   (NP test/NN)
#   in/IN
#   1979/CD
#   ,/,
#   when/WRB
#   President/NNP
#   Jimmy/NNP
#   Carter/NNP
#   ended/VBD
#   US/NNP
#   (NP diplomatic/JJ recognition/NN)
#   of/IN
#   Taiwan/NNP
#   in/IN
#   (NP order/NN)
#   to/TO
#   concentrate/VB
#   on/IN
#   burgeoning/VBG
#   ties/NNS
#   with/IN
#   China/NNP
#   ./.
#   The/DT
#   US/NNP
#   Congress/NNP
#   ,/,
#   responding/VBG
#   to/TO
#   (NP the/DT move/NN)
#   ,/,
#   passed/VBD
#   the/DT
#   Taiwan/NNP
#   Relations/NNP
#   Act/NNP
#   ,/,
#   which/WDT
#   promises/VBZ
#   to/TO
#   supply/VB
#   Taiwan/NNP
#   with/IN
#   defensive/JJ
#   weapons/NNS
#   ,/,
#   and/CC
#   stressed/VBD
#   that/IN
#   (NP any/DT attack/NN)
#   by/IN
#   China/NNP
#   would/MD
#   be/VB
#   considered/VBN
#   of/IN
#   ``/``
#   (NP grave/JJ concern/NN)
#   ''/''
#   to/TO
#   the/DT
#   US/NNP
#   ./.
#   Since/IN
#   then/RB
#   ,/,
#   US/NNP
#   (NP policy/NN)
#   has/VBZ
#   been/VBN
#   described/VBN
#   as/IN
#   one/CD
#   of/IN
#   ``/``
#   (NP strategic/JJ ambiguity/NN)
#   ''/''
#   ,/,
#   seeking/VBG
#   to/TO
#   balance/VB
#   China/NNP
#   's/POS
#   (NP emergence/NN)
#   as/IN
#   (NP a/DT regional/JJ power/NN)
#   with/IN
#   US/NNP
#   (NP admiration/NN)
#   for/IN
#   Taiwan/NNP
#   's/POS
#   (NP economic/JJ success/NN)
#   and/CC
#   (NP democratisation/NN)
#   ./.
#   (NP The/DT pivotal/JJ role/NN)
#   of/IN
#   the/DT
#   US/NNP
#   was/VBD
#   most/JJS
#   clearly/RB
#   shown/VBN
#   in/IN
#   1996/CD
#   ,/,
#   when/WRB
#   China/NNP
#   conducted/VBD
#   (NP provocative/JJ missile/NN)
#   tests/NNS
#   to/TO
#   try/VB
#   and/CC
#   influence/VB
#   Taiwan/NNP
#   's/POS
#   (NP first/JJ direct/JJ presidential/JJ election/NN)
#   ./.
#   In/IN
#   (NP response/NN)
#   ,/,
#   US/NNP
#   President/NNP
#   Bill/NNP
#   Clinton/NNP
#   ordered/VBD
#   the/DT
#   biggest/JJS
#   (NP display/NN)
#   of/IN
#   US/NNP
#   (NP military/JJ power/NN)
#   in/IN
#   Asia/NNP
#   since/IN
#   the/DT
#   Vietnam/NNP
#   War/NNP
#   ,/,
#   sending/VBG
#   ships/NNS
#   to/TO
#   the/DT
#   Taiwan/NNP
#   Strait/NNP
#   ,/,
#   and/CC
#   (NP a/DT clear/JJ message/NN)
#   to/TO
#   Beijing/NNP
#   ./.)

# %%
tree1 = nltk.Tree('NP',['Alick'])
print(tree1) 
tree2 = nltk.Tree('N',['Alick','Rabbit'])
print(tree2)
tree3 = nltk.Tree('S',[tree1,tree2])
print(tree3.label())
tree3.draw()
# Out:
# (NP Alick)
# (N Alick Rabbit)
# S

# %%
NER = ne_chunk(nltk.pos_tag(word_tokenize(strEx)), binary=False)

# %%
type(NER)
# Out:
# nltk.tree.Tree

# %%
print(NER)
# Out:
# (S
#   (GPE China/NNP)
#   sees/VBZ
#   (GPE Taiwan/NNP)
#   as/IN
#   a/DT
#   breakaway/NN
#   province/NN
#   that/WDT
#   will/MD
#   eventually/RB
#   be/VB
#   part/NN
#   of/IN
#   the/DT
#   country/NN
#   again/RB
#   ,/,
#   but/CC
#   many/JJ
#   (GPE Taiwanese/NNP)
#   want/VBP
#   a/DT
#   separate/JJ
#   nation/NN
#   ./.
#   The/DT
#   dispute/NN
#   with/IN
#   (GPE China/NNP)
#   has/VBZ
#   left/VBN
#   relations/NNS
#   frayed/VBN
#   and/CC
#   a/DT
#   constant/JJ
#   threat/NN
#   of/IN
#   a/DT
#   violent/NN
#   flare/NN
#   up/IN
#   that/DT
#   could/MD
#   drag/VB
#   the/DT
#   (ORGANIZATION US/NNP)
#   into/IN
#   the/DT
#   fray/NN
#   ./.
#   What/WP
#   is/VBZ
#   the/DT
#   history/NN
#   and/CC
#   source/NN
#   of/IN
#   this/DT
#   tension/NN
#   ?/.
#   The/DT
#   first/JJ
#   known/JJ
#   settlers/NNS
#   in/IN
#   (GPE Taiwan/NNP)
#   are/VBP
#   (GPE Austronesian/JJ)
#   tribal/JJ
#   people/NNS
#   thought/VBN
#   to/TO
#   have/VB
#   come/VBN
#   from/IN
#   modern/JJ
#   day/NN
#   southern/JJ
#   (GPE China/NNP)
#   ./.
#   The/DT
#   island/NN
#   first/RB
#   appears/VBZ
#   in/IN
#   (GPE Chinese/JJ)
#   records/NNS
#   in/IN
#   (GPE AD239/NNP)
#   ,/,
#   when/WRB
#   (GPE China/NNP)
#   sent/VBD
#   an/DT
#   expeditionary/JJ
#   force/NN
#   to/TO
#   explore/VB
#   -/:
#   a/DT
#   fact/NN
#   (GPE Beijing/NNP)
#   uses/VBZ
#   to/TO
#   back/VB
#   its/PRP$
#   territorial/JJ
#   claim/NN
#   ./.
#   After/IN
#   a/DT
#   brief/JJ
#   spell/NN
#   as/IN
#   a/DT
#   (GPE Dutch/JJ)
#   colony/NN
#   (/(
#   1624-1661/JJ
#   )/)
#   (GPE Taiwan/NNP)
#   was/VBD
#   unquestionably/RB
#   administered/VBN
#   by/IN
#   (GPE China/NNP)
#   's/POS
#   Qing/VBG
#   dynasty/NN
#   from/IN
#   1683/CD
#   to/TO
#   1895/CD
#   ./.
#   Starting/VBG
#   at/IN
#   the/DT
#   beginning/NN
#   of/IN
#   the/DT
#   17th/JJ
#   (ORGANIZATION Century/NNP)
#   ,/,
#   significant/JJ
#   numbers/NNS
#   of/IN
#   migrants/NNS
#   started/VBD
#   arriving/VBG
#   from/IN
#   (GPE China/NNP)
#   ,/,
#   often/RB
#   fleeing/VBG
#   turmoil/NN
#   or/CC
#   hardship/NN
#   ./.
#   Most/JJS
#   were/VBD
#   (PERSON Hoklo/NNP Chinese/NNP)
#   from/IN
#   (GPE Fujian/NNP)
#   (/(
#   (GPE Fukien/NNP)
#   )/)
#   province/NN
#   or/CC
#   were/VBD
#   (PERSON Hakka/NNP Chinese/NNP)
#   ,/,
#   largely/RB
#   from/IN
#   (GPE Guangdong/NNP)
#   ./.
#   The/DT
#   descendants/NNS
#   of/IN
#   these/DT
#   two/CD
#   migrations/NNS
#   now/RB
#   make/VBP
#   up/RP
#   by/IN
#   far/RB
#   the/DT
#   largest/JJS
#   population/NN
#   group/NN
#   ./.
#   In/IN
#   1895/CD
#   ,/,
#   following/VBG
#   (GPE Japan/NNP)
#   's/POS
#   victory/NN
#   in/IN
#   the/DT
#   First/JJ
#   Sino-Japanese/JJ
#   War/NNP
#   ,/,
#   the/DT
#   Qing/JJ
#   government/NN
#   had/VBD
#   no/DT
#   choice/NN
#   but/CC
#   to/TO
#   cede/VB
#   (GPE Taiwan/NNP)
#   to/TO
#   (GPE Japan/NNP)
#   ./.
#   But/CC
#   after/IN
#   World/NNP
#   War/NNP
#   Two/CD
#   ,/,
#   the/DT
#   (ORGANIZATION Republic/NNP)
#   of/IN
#   (GPE China/NNP)
#   -/:
#   one/CD
#   of/IN
#   the/DT
#   victors/NNS
#   -/:
#   began/VBD
#   ruling/VBG
#   (GPE Taiwan/NNP)
#   with/IN
#   the/DT
#   consent/NN
#   of/IN
#   its/PRP$
#   allies/NNS
#   the/DT
#   (ORGANIZATION US/NNP)
#   and/CC
#   (ORGANIZATION UK/NNP)
#   ,/,
#   after/IN
#   (GPE Japan/NNP)
#   surrendered/VBD
#   and/CC
#   relinquished/VBD
#   control/NN
#   of/IN
#   territory/NN
#   it/PRP
#   had/VBD
#   taken/VBN
#   from/IN
#   (GPE China/NNP)
#   ./.
#   However/RB
#   in/IN
#   the/DT
#   next/JJ
#   few/JJ
#   years/NNS
#   ,/,
#   (GPE Chiang/NNP)
#   's/POS
#   troops/NNS
#   were/VBD
#   beaten/VBN
#   back/RB
#   by/IN
#   the/DT
#   (ORGANIZATION Communist/NNP)
#   armies/NNS
#   under/IN
#   (PERSON Mao/NNP Zedong/NNP)
#   ./.
#   (PERSON Chiang/NNP)
#   and/CC
#   the/DT
#   remnants/NNS
#   of/IN
#   his/PRP$
#   (GPE Kuomintang/NNP)
#   (/(
#   (ORGANIZATION KMT/NNP)
#   )/)
#   government/NN
#   fled/VBD
#   to/TO
#   (GPE Taiwan/NNP)
#   in/IN
#   1949/CD
#   ./.
#   This/DT
#   group/NN
#   ,/,
#   referred/VBD
#   to/TO
#   as/IN
#   (GPE Mainland/NNP Chinese/NNP)
#   and/CC
#   then/RB
#   making/VBG
#   up/RP
#   1.5m/CD
#   people/NNS
#   ,/,
#   dominated/VBD
#   (GPE Taiwan/NNP)
#   's/POS
#   politics/NNS
#   for/IN
#   many/JJ
#   years/NNS
#   ,/,
#   even/RB
#   though/IN
#   they/PRP
#   only/RB
#   account/VBP
#   for/IN
#   14/CD
#   %/NN
#   of/IN
#   the/DT
#   population/NN
#   ./.
#   Having/VBG
#   inherited/VBN
#   an/DT
#   effective/JJ
#   dictatorship/NN
#   ,/,
#   facing/VBG
#   resistance/NN
#   from/IN
#   local/JJ
#   people/NNS
#   resentful/NN
#   of/IN
#   the/DT
#   228/CD
#   Massacre/NNP
#   and/CC
#   authoritarian/JJ
#   rule/NN
#   ,/,
#   and/CC
#   under/IN
#   pressure/NN
#   from/IN
#   a/DT
#   growing/VBG
#   democracy/NN
#   movement/NN
#   ,/,
#   (GPE Chiang/NNP)
#   's/POS
#   son/NN
#   ,/,
#   (PERSON Chiang/NNP Ching-kuo/NNP)
#   ,/,
#   began/VBD
#   allowing/VBG
#   a/DT
#   process/NN
#   of/IN
#   democratisation/NN
#   ,/,
#   which/WDT
#   eventually/RB
#   led/VBD
#   to/TO
#   the/DT
#   2000/CD
#   election/NN
#   of/IN
#   the/DT
#   island/NN
#   's/POS
#   first/JJ
#   non-KMT/JJ
#   president/NN
#   ,/,
#   (PERSON Chen/NNP Shui-bian/NNP)
#   ./.
#   Where/WRB
#   are/VBP
#   things/NNS
#   at/IN
#   now/RB
#   ?/.
#   After/IN
#   decades/NNS
#   of/IN
#   hostile/JJ
#   intentions/NNS
#   and/CC
#   angry/JJ
#   rhetoric/NN
#   ,/,
#   relations/NNS
#   between/IN
#   (GPE China/NNP)
#   and/CC
#   (GPE Taiwan/NNP)
#   started/VBD
#   improving/VBG
#   in/IN
#   the/DT
#   1980s/CD
#   ./.
#   (GPE China/NNP)
#   put/VBD
#   forward/RP
#   a/DT
#   formula/NN
#   ,/,
#   known/VBN
#   as/IN
#   ``/``
#   one/CD
#   country/NN
#   ,/,
#   two/CD
#   systems/NNS
#   ''/''
#   ,/,
#   under/IN
#   which/WDT
#   (GPE Taiwan/NNP)
#   would/MD
#   be/VB
#   given/VBN
#   significant/JJ
#   autonomy/NN
#   if/IN
#   it/PRP
#   accepted/VBD
#   (GPE Chinese/JJ)
#   reunification/NN
#   ./.
#   The/DT
#   offer/NN
#   was/VBD
#   rejected/VBN
#   ,/,
#   but/CC
#   (GPE Taiwan/NNP)
#   did/VBD
#   relax/VB
#   rules/NNS
#   on/IN
#   visits/NNS
#   to/TO
#   and/CC
#   investment/NN
#   in/IN
#   (GPE China/NNP)
#   ./.
#   It/PRP
#   also/RB
#   ,/,
#   in/IN
#   1991/CD
#   ,/,
#   proclaimed/VBD
#   the/DT
#   war/NN
#   with/IN
#   the/DT
#   (ORGANIZATION People/NNP)
#   's/POS
#   (ORGANIZATION Republic/NNP)
#   of/IN
#   (GPE China/NNP)
#   over/IN
#   ./.
#   There/EX
#   were/VBD
#   also/RB
#   limited/JJ
#   talks/NNS
#   between/IN
#   the/DT
#   two/CD
#   sides/NNS
#   '/POS
#   unofficial/JJ
#   representatives/NNS
#   ,/,
#   though/IN
#   (GPE China/NNP)
#   's/POS
#   insistence/NN
#   that/IN
#   the/DT
#   (ORGANIZATION Republic/NNP)
#   of/IN
#   (GPE China/NNP)
#   (/(
#   (ORGANIZATION ROC/NNP)
#   )/)
#   government/NN
#   is/VBZ
#   illegitimate/JJ
#   prevented/JJ
#   government-to-government/JJ
#   contact/NN
#   ./.
#   (PERSON Beijing/NNP)
#   became/VBD
#   alarmed/VBN
#   in/IN
#   2000/CD
#   ,/,
#   when/WRB
#   (GPE Taiwan/NNP)
#   elected/VBD
#   as/IN
#   president/NN
#   (PERSON Chen/NNP Shui-bian/NNP)
#   ,/,
#   who/WP
#   had/VBD
#   openly/RB
#   backed/VBN
#   independence/NN
#   ./.
#   Mr/NNP
#   (PERSON Chen/NNP)
#   was/VBD
#   re-elected/VBN
#   in/IN
#   2004/CD
#   ,/,
#   prompting/VBG
#   (GPE China/NNP)
#   to/TO
#   pass/VB
#   a/DT
#   so-called/JJ
#   anti-secession/NN
#   law/NN
#   in/IN
#   2005/CD
#   ,/,
#   stating/VBG
#   (GPE China/NNP)
#   's/POS
#   right/NN
#   to/TO
#   use/VB
#   ``/``
#   non-peaceful/JJ
#   means/NNS
#   ''/''
#   against/IN
#   (GPE Taiwan/NNP)
#   if/IN
#   it/PRP
#   tried/VBD
#   to/TO
#   secede/VB
#   from/IN
#   (GPE China/NNP)
#   ./.
#   In/IN
#   2008/CD
#   ,/,
#   (PERSON Ma/NNP Ying-jeou/NNP)
#   was/VBD
#   elected/VBN
#   president/NN
#   ./.
#   He/PRP
#   sought/VBD
#   to/TO
#   improve/VB
#   relations/NNS
#   with/IN
#   (GPE China/NNP)
#   ,/,
#   mainly/RB
#   through/IN
#   economic/JJ
#   agreements/NNS
#   ./.
#   In/IN
#   elections/NNS
#   in/IN
#   January/NNP
#   2016/CD
#   ,/,
#   (PERSON Tsai/NNP Ing-wen/NNP)
#   defeated/VBD
#   (ORGANIZATION Kuomintang/NNP)
#   party/NN
#   candidate/NN
#   (PERSON Eric/NNP Chu/NNP)
#   ./.
#   Mr/NNP
#   Ma/NNP
#   was/VBD
#   barred/VBN
#   by/IN
#   (GPE Taiwan/NNP)
#   's/POS
#   constitution/NN
#   from/IN
#   the/DT
#   seeking/VBG
#   a/DT
#   third/JJ
#   term/NN
#   in/IN
#   office/NN
#   ./.
#   Ms/NNP
#   Tsai/NNP
#   leads/VBZ
#   the/DT
#   (ORGANIZATION Democratic/JJ Progressive/NNP Party/NNP)
#   (/(
#   (ORGANIZATION DPP/NNP)
#   )/)
#   ,/,
#   which/WDT
#   leans/VBZ
#   towards/NNS
#   independence/NN
#   from/IN
#   (GPE China/NNP)
#   ./.
#   In/IN
#   December/NNP
#   2016/CD
#   ,/,
#   she/PRP
#   spoke/VBD
#   to/TO
#   the/DT
#   then/RB
#   (ORGANIZATION US/NNP)
#   President-elect/NNP
#   (PERSON Donald/NNP Trump/NNP)
#   in/IN
#   a/DT
#   phone/NN
#   call/NN
#   ,/,
#   in/IN
#   what/WP
#   was/VBD
#   a/DT
#   break/NN
#   with/IN
#   (GSP US/JJ)
#   policy/NN
#   set/VBN
#   in/IN
#   1979/CD
#   when/WRB
#   formal/JJ
#   relations/NNS
#   were/VBD
#   cut/VBN
#   ./.
#   So/IN
#   what/WP
#   is/VBZ
#   (GPE Taiwan/NNP)
#   ?/.
#   There/EX
#   is/VBZ
#   disagreement/JJ
#   and/CC
#   confusion/NN
#   about/IN
#   what/WP
#   (GPE Taiwan/NNP)
#   is/VBZ
#   ,/,
#   and/CC
#   even/RB
#   what/WP
#   it/PRP
#   should/MD
#   be/VB
#   called/VBN
#   ./.
#   (PERSON Chiang/NNP Kai-shek/NNP)
#   's/POS
#   (ORGANIZATION Republic/NNP)
#   of/IN
#   (GPE China/NNP)
#   (/(
#   (ORGANIZATION ROC/NNP)
#   )/)
#   government/NN
#   ,/,
#   which/WDT
#   fled/VBD
#   the/DT
#   mainland/NN
#   to/TO
#   (GPE Taiwan/NNP)
#   in/IN
#   1949/CD
#   ,/,
#   at/IN
#   first/RB
#   claimed/VBN
#   to/TO
#   represent/VB
#   the/DT
#   whole/NN
#   of/IN
#   (GPE China/NNP)
#   ,/,
#   which/WDT
#   it/PRP
#   intended/VBD
#   to/TO
#   re-occupy/NN
#   ./.
#   It/PRP
#   held/VBD
#   (GPE China/NNP)
#   's/POS
#   seat/NN
#   on/IN
#   the/DT
#   (ORGANIZATION United/NNP Nations/NNP)
#   (ORGANIZATION Security/NNP Council/NNP)
#   and/CC
#   was/VBD
#   recognised/VBN
#   by/IN
#   many/JJ
#   (LOCATION Western/JJ)
#   nations/NNS
#   as/IN
#   the/DT
#   only/JJ
#   (GPE Chinese/JJ)
#   government/NN
#   ./.
#   But/CC
#   in/IN
#   1971/CD
#   ,/,
#   the/DT
#   (ORGANIZATION UN/NNP)
#   switched/VBD
#   diplomatic/JJ
#   recognition/NN
#   to/TO
#   (GPE Beijing/NNP)
#   and/CC
#   the/DT
#   (ORGANIZATION ROC/NNP)
#   government/NN
#   was/VBD
#   forced/VBN
#   out/RP
#   ./.
#   Since/IN
#   then/RB
#   the/DT
#   number/NN
#   of/IN
#   countries/NNS
#   that/WDT
#   recognise/VBP
#   the/DT
#   (ORGANIZATION ROC/NNP)
#   government/NN
#   diplomatically/RB
#   has/VBZ
#   fallen/VBN
#   to/TO
#   about/IN
#   20/CD
#   ./.
#   (GPE China/NNP)
#   regards/NNS
#   (GPE Taiwan/NNP)
#   as/IN
#   a/DT
#   breakaway/NN
#   province/NN
#   which/WDT
#   it/PRP
#   has/VBZ
#   vowed/VBN
#   to/TO
#   retake/VB
#   ,/,
#   by/IN
#   force/NN
#   if/IN
#   necessary/JJ
#   ./.
#   But/CC
#   (GPE Taiwan/NNP)
#   's/POS
#   leaders/NNS
#   say/VBP
#   it/PRP
#   is/VBZ
#   clearly/RB
#   much/RB
#   more/JJR
#   than/IN
#   a/DT
#   province/NN
#   ,/,
#   arguing/VBG
#   that/IN
#   it/PRP
#   is/VBZ
#   a/DT
#   sovereign/JJ
#   state/NN
#   ./.
#   It/PRP
#   has/VBZ
#   its/PRP$
#   own/JJ
#   constitution/NN
#   ,/,
#   democratically-elected/JJ
#   leaders/NNS
#   ,/,
#   and/CC
#   about/IN
#   300,000/CD
#   active/JJ
#   troops/NNS
#   in/IN
#   its/PRP$
#   armed/JJ
#   forces/NNS
#   ./.
#   Given/VBN
#   the/DT
#   huge/JJ
#   divide/NN
#   between/IN
#   these/DT
#   two/CD
#   positions/NNS
#   ,/,
#   most/JJS
#   other/JJ
#   countries/NNS
#   seem/VBP
#   happy/JJ
#   to/TO
#   accept/VB
#   the/DT
#   current/JJ
#   ambiguity/NN
#   ,/,
#   whereby/WRB
#   (GPE Taiwan/NNP)
#   has/VBZ
#   most/JJS
#   of/IN
#   the/DT
#   characteristics/NNS
#   of/IN
#   an/DT
#   independent/JJ
#   state/NN
#   ,/,
#   even/RB
#   if/IN
#   its/PRP$
#   legal/JJ
#   status/NN
#   remains/VBZ
#   unclear/JJ
#   ./.
#   How/WRB
#   much/JJ
#   of/IN
#   an/DT
#   issue/NN
#   is/VBZ
#   independence/VBN
#   in/IN
#   (GPE Taiwan/NNP)
#   ?/.
#   While/IN
#   political/JJ
#   progress/NN
#   has/VBZ
#   been/VBN
#   slow/JJ
#   ,/,
#   links/NNS
#   between/IN
#   the/DT
#   two/CD
#   peoples/NNS
#   and/CC
#   economies/NNS
#   have/VBP
#   grown/VBN
#   sharply/RB
#   ./.
#   (GPE Taiwanese/JJ)
#   companies/NNS
#   have/VBP
#   invested/VBN
#   about/IN
#   $/$
#   60bn/CD
#   (/(
#   £40bn/NN
#   )/)
#   in/IN
#   (GPE China/NNP)
#   ,/,
#   and/CC
#   up/RB
#   to/TO
#   one/CD
#   million/CD
#   Taiwanese/NNPS
#   now/RB
#   live/VBP
#   there/RB
#   ,/,
#   many/JJ
#   running/VBG
#   (GPE Taiwanese/JJ)
#   factories/NNS
#   ./.
#   Some/DT
#   Taiwanese/JJ
#   worry/VBP
#   their/PRP$
#   economy/NN
#   is/VBZ
#   now/RB
#   dependent/JJ
#   on/IN
#   (GPE China/NNP)
#   ./.
#   Others/NNS
#   point/VBP
#   out/RP
#   that/IN
#   closer/JJR
#   business/NN
#   ties/NNS
#   makes/VBZ
#   (GPE Chinese/JJ)
#   military/JJ
#   action/NN
#   less/RBR
#   likely/RB
#   ,/,
#   because/IN
#   of/IN
#   the/DT
#   cost/NN
#   to/TO
#   (GPE China/NNP)
#   's/POS
#   own/JJ
#   economy/NN
#   ./.
#   A/DT
#   controversial/JJ
#   trade/NN
#   agreement/NN
#   sparked/VBD
#   the/DT
#   ``/``
#   (ORGANIZATION Sunflower/NNP)
#   Movement/NNP
#   ''/''
#   in/IN
#   2014/CD
#   where/WRB
#   students/NNS
#   and/CC
#   activists/NNS
#   occupied/VBD
#   (GPE Taiwan/NNP)
#   's/POS
#   parliament/NN
#   protesting/NN
#   against/IN
#   what/WP
#   they/PRP
#   call/VBP
#   (GPE China/NNP)
#   's/POS
#   growing/VBG
#   influence/NN
#   over/IN
#   (GPE Taiwan/NNP)
#   ./.
#   Officially/RB
#   ,/,
#   the/DT
#   (ORGANIZATION Democratic/JJ Progressive/NNP Party/NNP)
#   (/(
#   (ORGANIZATION DPP/NNP)
#   )/)
#   still/RB
#   favours/VBZ
#   eventual/JJ
#   independence/NN
#   for/IN
#   (GPE Taiwan/NNP)
#   ,/,
#   while/IN
#   the/DT
#   (ORGANIZATION KMT/NNP)
#   favours/VBZ
#   eventual/JJ
#   re-unification/NN
#   ./.
#   (PERSON Opinion/NNP)
#   polls/VBZ
#   show/VBP
#   only/RB
#   a/DT
#   small/JJ
#   minority/NN
#   of/IN
#   (GPE Taiwanese/JJ)
#   support/NN
#   pursuing/VBG
#   one/CD
#   or/CC
#   the/DT
#   other/JJ
#   at/IN
#   the/DT
#   moment/NN
#   ,/,
#   with/IN
#   most/RBS
#   preferring/VBG
#   to/TO
#   stick/VB
#   with/IN
#   the/DT
#   current/JJ
#   middle/NN
#   ground/NN
#   ./.
#   Yet/CC
#   more/JJR
#   and/CC
#   more/JJR
#   people/NNS
#   say/VBP
#   they/PRP
#   feel/VBP
#   (GPE Taiwanese/JJ)
#   rather/RB
#   than/IN
#   (GPE Chinese/NNPS)
#   ./.
#   (PERSON Support/NNP)
#   for/IN
#   the/DT
#   (ORGANIZATION DPP/NNP)
#   increased/VBD
#   at/IN
#   the/DT
#   January/NNP
#   2016/CD
#   election/NN
#   ./.
#   This/DT
#   was/VBD
#   partly/RB
#   because/IN
#   of/IN
#   dissatisfaction/NN
#   with/IN
#   the/DT
#   (ORGANIZATION KMT/NNP)
#   's/POS
#   handling/NN
#   of/IN
#   economic/JJ
#   matters/NNS
#   ,/,
#   from/IN
#   the/DT
#   wealth/NN
#   gap/NN
#   to/TO
#   high/JJ
#   housing/NN
#   prices/NNS
#   ,/,
#   and/CC
#   partly/RB
#   because/IN
#   of/IN
#   worries/NNS
#   that/WDT
#   Mr/NNP
#   Ma/NNP
#   's/POS
#   administration/NN
#   was/VBD
#   making/VBG
#   (GPE Taiwan/NNP)
#   too/RB
#   dependent/JJ
#   on/IN
#   (GPE Beijing/NNP)
#   ./.
#   What/WP
#   role/NN
#   does/VBZ
#   the/DT
#   (GSP US/NNP)
#   play/NN
#   ?/.
#   The/DT
#   (ORGANIZATION US/NNP)
#   is/VBZ
#   by/IN
#   far/RB
#   (GPE Taiwan/NNP)
#   's/POS
#   most/RBS
#   important/JJ
#   friend/NN
#   ,/,
#   and/CC
#   its/PRP$
#   only/JJ
#   ally/NN
#   ./.
#   The/DT
#   relationship/NN
#   ,/,
#   forged/VBN
#   during/IN
#   World/NNP
#   War/NNP
#   Two/CD
#   and/CC
#   the/DT
#   Cold/NNP
#   War/NNP
#   ,/,
#   underwent/VBD
#   its/PRP$
#   sternest/JJS
#   test/NN
#   in/IN
#   1979/CD
#   ,/,
#   when/WRB
#   President/NNP
#   (PERSON Jimmy/NNP Carter/NNP)
#   ended/VBD
#   (GSP US/NNP)
#   diplomatic/JJ
#   recognition/NN
#   of/IN
#   (GPE Taiwan/NNP)
#   in/IN
#   order/NN
#   to/TO
#   concentrate/VB
#   on/IN
#   burgeoning/VBG
#   ties/NNS
#   with/IN
#   (GPE China/NNP)
#   ./.
#   The/DT
#   (ORGANIZATION US/NNP Congress/NNP)
#   ,/,
#   responding/VBG
#   to/TO
#   the/DT
#   move/NN
#   ,/,
#   passed/VBD
#   the/DT
#   (GPE Taiwan/NNP)
#   Relations/NNP
#   Act/NNP
#   ,/,
#   which/WDT
#   promises/VBZ
#   to/TO
#   supply/VB
#   (GPE Taiwan/NNP)
#   with/IN
#   defensive/JJ
#   weapons/NNS
#   ,/,
#   and/CC
#   stressed/VBD
#   that/IN
#   any/DT
#   attack/NN
#   by/IN
#   (GPE China/NNP)
#   would/MD
#   be/VB
#   considered/VBN
#   of/IN
#   ``/``
#   grave/JJ
#   concern/NN
#   ''/''
#   to/TO
#   the/DT
#   (GSP US/NNP)
#   ./.
#   Since/IN
#   then/RB
#   ,/,
#   (GSP US/NNP)
#   policy/NN
#   has/VBZ
#   been/VBN
#   described/VBN
#   as/IN
#   one/CD
#   of/IN
#   ``/``
#   strategic/JJ
#   ambiguity/NN
#   ''/''
#   ,/,
#   seeking/VBG
#   to/TO
#   balance/VB
#   (GPE China/NNP)
#   's/POS
#   emergence/NN
#   as/IN
#   a/DT
#   regional/JJ
#   power/NN
#   with/IN
#   (GSP US/NNP)
#   admiration/NN
#   for/IN
#   (GPE Taiwan/NNP)
#   's/POS
#   economic/JJ
#   success/NN
#   and/CC
#   democratisation/NN
#   ./.
#   The/DT
#   pivotal/JJ
#   role/NN
#   of/IN
#   the/DT
#   (ORGANIZATION US/NNP)
#   was/VBD
#   most/JJS
#   clearly/RB
#   shown/VBN
#   in/IN
#   1996/CD
#   ,/,
#   when/WRB
#   (GPE China/NNP)
#   conducted/VBD
#   provocative/JJ
#   missile/NN
#   tests/NNS
#   to/TO
#   try/VB
#   and/CC
#   influence/VB
#   (GPE Taiwan/NNP)
#   's/POS
#   first/JJ
#   direct/JJ
#   presidential/JJ
#   election/NN
#   ./.
#   In/IN
#   response/NN
#   ,/,
#   (GPE US/NNP)
#   President/NNP
#   (PERSON Bill/NNP Clinton/NNP)
#   ordered/VBD
#   the/DT
#   biggest/JJS
#   display/NN
#   of/IN
#   (GPE US/NNP)
#   military/JJ
#   power/NN
#   in/IN
#   (GPE Asia/NNP)
#   since/IN
#   the/DT
#   (ORGANIZATION Vietnam/NNP War/NNP)
#   ,/,
#   sending/VBG
#   ships/NNS
#   to/TO
#   the/DT
#   (GPE Taiwan/NNP Strait/NNP)
#   ,/,
#   and/CC
#   a/DT
#   clear/JJ
#   message/NN
#   to/TO
#   (GPE Beijing/NNP)
#   ./.)

# %%
def get_continuous_chunks(text, label):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    prev = None
    continuous_chunk = []
    current_chunk = []

    for subtree in chunked:
        if type(subtree) == Tree and subtree.label() == label:
            current_chunk.append(" ".join([token for token, pos in subtree.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue

    return continuous_chunk

# %%
get_continuous_chunks(strEx, 'GPE')
# Out:
# ['China',
#  'Taiwan',
#  'Taiwanese',
#  'China Taiwan',
#  'Austronesian',
#  'China Chinese',
#  'AD239',
#  'China Beijing',
#  'Dutch',
#  'Taiwan China',
#  'China Fujian',
#  'Fukien',
#  'Guangdong',
#  'Japan',
#  'Taiwan Japan',
#  'China Taiwan Japan',
#  'China Chiang',
#  'Kuomintang',
#  'Taiwan Mainland Chinese',
#  'Taiwan Chiang',
#  'China Taiwan China',
#  'Taiwan Chinese',
#  'Taiwan China China',
#  'China China',
#  'Taiwan China China Taiwan',
#  'China China Taiwan',
#  'China Taiwan Taiwan',
#  'China Taiwan China China',
#  'Chinese',
#  'Beijing',
#  'China Taiwan Taiwan Taiwan',
#  'Taiwan Taiwanese',
#  'China Taiwanese',
#  'China Chinese China',
#  'Taiwan China Taiwan',
#  'Taiwan Taiwanese Taiwanese',
#  'Chinese Taiwan',
#  'Beijing Taiwan',
#  'Taiwan China Taiwan Taiwan',
#  'China China Taiwan China',
#  'Taiwan US',
#  'US',
#  'Asia',
#  'Taiwan Strait']

# %%
get_continuous_chunks(strEx, 'ORGANIZATION')
# Out:
# ['US',
#  'Century',
#  'Republic',
#  'US UK',
#  'Communist',
#  'KMT',
#  'People',
#  'Republic Republic',
#  'ROC',
#  'Kuomintang',
#  'Democratic Progressive Party',
#  'DPP',
#  'US Republic',
#  'ROC United Nations Security Council',
#  'UN',
#  'ROC ROC',
#  'Sunflower',
#  'Democratic Progressive Party DPP',
#  'KMT DPP',
#  'KMT US',
#  'US Congress',
#  'US Vietnam War']

# %%
get_continuous_chunks(strEx, 'PERSON')
# Out:
# ['Hoklo Chinese',
#  'Hakka Chinese',
#  'Mao Zedong',
#  'Chiang',
#  'Chiang Ching-kuo',
#  'Chen Shui-bian',
#  'Beijing',
#  'Chen Shui-bian Chen',
#  'Ma Ying-jeou',
#  'Tsai Ing-wen',
#  'Eric Chu',
#  'Donald Trump',
#  'Chiang Kai-shek',
#  'Opinion',
#  'Support',
#  'Jimmy Carter',
#  'Bill Clinton']
